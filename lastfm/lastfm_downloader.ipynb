# %%
# https://www.last.fm/api/accounts

import json

with open("data/credentials.json", "r") as file:
    credentials = json.load(file)
    last_fm_cr = credentials['last_fm']
    key = last_fm_cr['KEY']
    username = last_fm_cr['USERNAME']

# %%
# how long to pause between consecutive API requests
pause_duration = 0.2

# %%
import requests
import json
import time
import pandas as pd

# %%
url = 'https://ws.audioscrobbler.com/2.0/?method=user.get{}&user={}&api_key={}&limit={}&extended={}&page={}&format=json'
limit = 200 #api lets you retrieve up to 200 records per call
extended = 0 #api lets you retrieve extended data for each track, 0=no, 1=yes
page = 1 #page of results to start retrieving at

# %%
method = 'toptracks'
request_url = url.format(method, username, key, limit, extended, page)
artist_names = []
track_names = []
play_counts = []
response = requests.get(request_url).json()
for item in response[method]['track']:
    artist_names.append(item['artist']['name'])
    track_names.append(item['name'])
    play_counts.append(item['playcount'])

top_tracks = pd.DataFrame()
top_tracks['artist'] = artist_names
top_tracks['track'] = track_names
top_tracks['play_count'] = play_counts
top_tracks.to_csv('data/lastfm_top_tracks.csv', index=None, encoding='utf-8')
top_tracks.head()
# Out:
#                              artist                 track play_count
# 0  King Gizzard & The Lizard Wizard     Mars For The Rich         11
# 1                           Lucifer        Before the Sun         11
# 2                             Opeth                 Bleak         11
# 3                             Opeth               Harvest         11
# 4                             Opeth  The Funeral Portrait         11

# %%
method = 'topartists'
request_url = url.format(method, username, key, limit, extended, page)
artist_names = []
play_counts = []
response = requests.get(request_url).json()
for item in response[method]['artist']:
    artist_names.append(item['name'])
    play_counts.append(item['playcount'])

top_artists = pd.DataFrame()
top_artists['artist'] = artist_names
top_artists['play_count'] = play_counts
top_artists.to_csv('data/lastfm_top_artists.csv', index=None, encoding='utf-8')
top_artists.head()
# Out:
#                              artist play_count
# 0                             Opeth        668
# 1         Between the Buried and Me        186
# 2  King Gizzard & The Lizard Wizard        165
# 3                           Lucifer        154
# 4                            Gojira        139

# %%
method = 'topalbums'
request_url = url.format(method, username, key, limit, extended, page)
artist_names = []
album_names = []
play_counts = []
response = requests.get(request_url).json()
for item in response[method]['album']:
    artist_names.append(item['artist']['name'])
    album_names.append(item['name'])
    play_counts.append(item['playcount'])

top_albums = pd.DataFrame()
top_albums['artist'] = artist_names
top_albums['album'] = album_names
top_albums['play_count'] = play_counts
top_albums.to_csv('data/lastfm_top_albums.csv', index=None, encoding='utf-8')
top_albums.head()
# Out:
#                              artist                       album play_count
# 0         Between the Buried and Me               Coma Ecliptic         84
# 1  King Gizzard & The Lizard Wizard       Infest the Rats' Nest         84
# 2                             Opeth             Blackwater Park         79
# 3                            Gojira         From Mars to Sirius         76
# 4                             Opeth  Heritage (Special Edition)         70

# %%
def get_scrobbles(method='recenttracks', username=username, key=key, limit=200, extended=0, page=1, pages=0):
    '''
    method: api method
    username/key: api credentials
    limit: api lets you retrieve up to 200 records per call
    extended: api lets you retrieve extended data for each track, 0=no, 1=yes
    page: page of results to start retrieving at
    pages: how many pages of results to retrieve. if 0, get as many as api can return.
    '''
    # initialize url and lists to contain response fields
    url = 'https://ws.audioscrobbler.com/2.0/?method=user.get{}&user={}&api_key={}&limit={}&extended={}&page={}&format=json'
    responses = []
    artist_names = []
    artist_mbids = []
    album_names = []
    album_mbids = []
    track_names = []
    track_mbids = []
    timestamps = []
    
    # make first request, just to get the total number of pages
    request_url = url.format(method, username, key, limit, extended, page)
    response = requests.get(request_url).json()
    total_pages = int(response[method]['@attr']['totalPages'])
    if pages > 0:
        total_pages = min([total_pages, pages])
        
    print('{} total pages to retrieve'.format(total_pages))
    
    # request each page of data one at a time
    for page in range(1, int(total_pages) + 1, 1):
        if page % 10 == 0: print(page, end=' ')
        time.sleep(pause_duration)
        request_url = url.format(method, username, key, limit, extended, page)
        responses.append(requests.get(request_url))
    
    # parse the fields out of each scrobble in each page (aka response) of scrobbles
    for response in responses:
        scrobbles = response.json()
        for scrobble in scrobbles[method]['track']:
            # only retain completed scrobbles (aka, with timestamp and not 'now playing')
            if 'date' in scrobble.keys():
                artist_names.append(scrobble['artist']['#text'])
                artist_mbids.append(scrobble['artist']['mbid'])
                album_names.append(scrobble['album']['#text'])
                album_mbids.append(scrobble['album']['mbid'])
                track_names.append(scrobble['name'])
                track_mbids.append(scrobble['mbid'])
                timestamps.append(scrobble['date']['uts'])
                
    # create and populate a dataframe to contain the data
    df = pd.DataFrame()
    df['artist'] = artist_names
    df['artist_mbid'] = artist_mbids
    df['album'] = album_names
    df['album_mbid'] = album_mbids
    df['track'] = track_names
    df['track_mbid'] = track_mbids
    df['timestamp'] = timestamps
    df['datetime'] = pd.to_datetime(df['timestamp'].astype(int), unit='s')
    
    return df

# %%
# get all scrobbled tracks ever, in order of recency (pages=0 to get all)
scrobbles = get_scrobbles(pages=0)
# Out:
# 34 total pages to retrieve
# 10 20 30

# %%
# save the dataset
scrobbles.to_csv('data/lastfm_scrobbles.csv', index=None, encoding='utf-8')
print('{:,} total rows'.format(len(scrobbles)))
scrobbles.head()
# Out:
# 6,735 total rows
#                 artist                           artist_mbid  \
# 0     All That Remains  4f8b7186-b2a2-40db-97ae-6e1cd46d57b1
# 1        Chimp Spanner  a9d72c8b-fea3-4927-9521-156e6fe05f37
# 2            Lady Gaga  650e7db6-b795-4eb5-a702-5ea2fc46c848
# 3                Kyuss  ea0f2a37-7007-4217-a812-396227f5013a
# 4  Outrun The Sunlight  388cfcf7-a7a4-4a54-b47e-3fadf2475205
#
#                  album                            album_mbid  \
# 0      For We Are Many  00e40879-8672-45f6-9172-72b891a955d4
# 1  All Roads Lead Here  5cdbd6b6-4644-4d5f-87a7-15809be88520
# 2           Chromatica  18b53118-01bb-4ed8-b21e-81f7b9c26464
# 3        Green Machine  9799ed6a-88b2-4d3e-9592-2cdb851172e6
# 4             Terrapin  4a45d00e-8e0e-47c9-9eea-dc803b44c39c
#
#                              track                            track_mbid  \
# 0                    The Last Time  2fea6a59-f18c-3fc1-ae81-998bacc4731d
# 1                          Engrams  0440be26-f1fb-3556-b375-912a4c665950
# 2                      Stupid Love  08845e2d-cfb7-4aaa-b529-532c9c38fa90
# 3                  Mondo Generator  30e03a93-6f7f-4c72-ba28-9f537d35dbbd
# 4  Where Every Word Spoken, Speaks  60e98521-a97a-4247-9cca-3a403404d505
#
#     timestamp            datetime
# 0  1611969776 2021-01-30 01:22:56
# 1  1611969629 2021-01-30 01:20:29
# 2  1611899696 2021-01-29 05:54:56
# 3  1611883424 2021-01-29 01:23:44
# 4  1611883243 2021-01-29 01:20:43
